# %%
import numpy as np
import math
import statsmodels.api as sm
import imblearn
from tqdm.notebook import tqdm
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms import bipartite, community 
from numpy.random import choice
import itertools

# %%
cbd = pd.read_csv('deals.csv')
cbi = pd.read_csv('investors.csv')
cbd = cbd.drop_duplicates()
cbi = cbi.drop_duplicates()

# %%
cbd.columns
# Out:
# Index(['target_name', 'stage', 'size', 'date', 'investors_name', 'url',
#        'description', 'industry', 'target_country', 'target_collections',
#        'target_status', 'target_ID', 'target_founded', 'round_simp',
#        'target_continent', 'target_state', 'target_city', 'target_street',
#        'target_people', 'target_competitors'],
#       dtype='object')

# %%
cbd[cbd['target_country'] =='Germany']
# Out:
#                           target_name                  stage      size  \
# 593                      TTNI medical  Incubator/Accelerator       NaN
# 637                          IIdea AG               Series C       NaN
# 685         IIngenium Pharmaceuticals        Other Investors       NaN
# 740                          HHemoteq        Other Investors       NaN
# 1012   LLTS Lohmann Therapie-Systeme…        Other Investors       NaN
# ...                               ...                    ...       ...
# 97808                           XXell               Acquired       NaN
# 97814             TTopas Therapeutics          Series B - II   $21.39M
# 97835            mmk2 Biotechnologies                   Seed       NaN
# 97851                        TT-Knife               Series B  $110.00M
# 97906              HHMNC Brain Health       Convertible Note   $10.68M
#
#              date                                     investors_name  \
# 593           NaN                         Emerging Technology Center
# 637           NaN  Undisclosed Investors,Gilde Healthcare Partner...
# 685           NaN                           Thuja Capital Management
# 740           NaN                          Earlybird Venture Capital
# 1012          NaN                                       BWK,Novartis
# ...           ...                                                ...
# 97808  07/29/2021                                          Sartorius
# 97814  07/29/2021  EMBL Ventures,Gimv,Epidarex Capital,BioMedPart...
# 97835  07/29/2021  Occident Management,Undisclosed Angel Investor...
# 97851  08/02/2021  Fidelity Investments,Versant Ventures,Qatar In...
# 97906  08/03/2021  Carsten Maschmeyer,GVB Family Office,Jahr Hold...
#
#                            url  \
# 593             tni-medical.de
# 637                        NaN
# 685            ingenium-ag.com
# 740                 hemoteq.de
# 1012             ltslohmann.de
# ...                        ...
# 97808                  xell.ag
# 97814  topas-therapeutics.com…
# 97835                  mk2.bio
# 97851              t-knife.com
# 97906                  hmnc.de
#
#                                              description  \
# 593    TNI medical develops, produces, and sells devi...
# 637    IDEA AG (IDEA) is a pharmaceutical company, ba...
# 685    Ingenium focuses on phenotype-driven target di...
# 740    Hemoteq develops coating solutions for combina...
# 1012   LTS is the global market leader in the develop...
# ...                                                  ...
# 97808  Xell is a globally active biotech company with...
# 97814  Topas Therapeutics is a biotechnology company ...
# 97835  mk2 Biotechnologies develops produces & invest...
# 97851  T-knife is a German biotech company developing...
# 97906  HMNC Brain Health specializes in depression an...
#
#                            industry target_country  \
# 593     Medical Devices & Equipment        Germany
# 637                Drug Development        Germany
# 685                   Biotechnology        Germany
# 740                   Biotechnology        Germany
# 1012   Medical Equipment & Supplies        Germany
# ...                             ...            ...
# 97808                 Biotechnology        Germany
# 97814                 Biotechnology        Germany
# 97835                 Biotechnology        Germany
# 97851                 Biotechnology        Germany
# 97906              Drug Development        Germany
#
#                                       target_collections   target_status  \
# 593                                      Medical Devices        Acquired
# 637              Pharma Startups and Biopharmaceuticals…  Alive / Active
# 685     Smart Money VCs (2017-2019) and Pharma Startups…        Acquired
# 740                                      Pharma Startups        Acquired
# 1012                                                 NaN  Alive / Active
# ...                                                  ...             ...
# 97808                                                NaN        Acquired
# 97814  Pharma Startups, Nanobiotechnology and Biophar...  Alive / Active
# 97835                                                NaN  Alive / Active
# 97851  Regenerative Medicine, Biopharmaceuticals and ...  Alive / Active
# 97906                                                NaN  Alive / Active
#
#        target_ID  target_founded        round_simp target_continent  \
# 593        23423          2007.0         Incubator           Europe
# 637        91779             NaN          Series C           Europe
# 685        89908             NaN   Other Investors           Europe
# 740        23967          1999.0   Other Investors           Europe
# 1012      186370          1984.0   Other Investors           Europe
# ...          ...             ...               ...              ...
# 97808     662113          2009.0       Acquisition           Europe
# 97814     251563             NaN          Series B           Europe
# 97835     662965          2020.0              Seed           Europe
# 97851     490489          2018.0          Series B           Europe
# 97906     663951          2010.0  Convertible Note           Europe
#
#       target_state target_city                 target_street  \
# 593            NaN    Wurzburg               Hofmannstraße 8
# 637            NaN         NaN                           NaN
# 685            NaN         NaN                           NaN
# 740            NaN    Würselen             Adenauerstraße 15
# 1012           NaN   Andernach               Lohmannstraße 2
# ...            ...         ...                           ...
# 97808          NaN   Bielefeld         Alte Verler Strasse 1
# 97814          NaN     Hamburg         Falkenried 88 Suite A
# 97835          NaN      Munich                 Fallstrasse 9
# 97851          NaN      Berlin        Robert-Roessle-Str. 10
# 97906          NaN     München  Wilhelm-Wagenfeld-Straße 20…
#
#                                            target_people  \
# 593                                    Ewald Anger (COO)
# 637    Gosse Bruinsma (CEO),Stefan Mazgareanu (SVP),J...
# 685          Michael Nehls (CEO),Stephen Freedman (EVP)…
# 740    Michael Hoffmann (CEO),Thomas Loewen (CFO),Rol...
# 1012                                                 NaN
# ...                                                  ...
# 97808                                                NaN
# 97814  Klaus Martin (CEO),Rupert Sandbrink (Chief Med...
# 97835                                                NaN
# 97851  Elisa Kieback (CEO),Eugen Leo (Chief Medical O...
# 97906                                                NaN
#
#                                       target_competitors
# 593    Bg Medicine,CardioInsight Technologies,Cathete...
# 637                                                  NaN
# 685                                                  NaN
# 740                                                  NaN
# 1012                                                 NaN
# ...                                                  ...
# 97808                                                NaN
# 97814                                                NaN
# 97835                                                NaN
# 97851                                                NaN
# 97906                                                NaN
#
# [1889 rows x 20 columns]
