# %%
#experiment

import pandas as pd
import os
import networkx as nx
import matplotlib.pyplot as plt
import itertools

# %%
investordb=pd.read_excel(os.path.expanduser('~/Documents/Thesis/EVERYTHING.xlsx'),sheet_name=2)

# %%
startingfileusing=startingfile.iloc[]
# Out:
#        Unnamed: 0  Unnamed: 0.1                     Investors  \
# 0            3504         18290                           212
# 1            3495          1956                           415
# 2            7835         17952                         21212
# 3           18577          5696                 .406 Ventures
# 4           10650          3659  (SVTC) + Constellar Ventures
# ...           ...           ...                           ...
# 18493        6750         16414           Zynik Capital Corp.
# 18494       10096         13865                    ZZ Capital
# 18495        1097         15525                       ёpeople
# 18496        7422          3543                           NaN
# 18497       11617         10627                           NaN
#
#                                       investor_location  \
# 0                    ['Istanbul', 'Istanbul', 'Turkey']
# 1      ['San Francisco', 'California', 'United States']
# ...

# %%
investordb.iloc[:,[1,6]]
# Out:
#                     Organisation            Investors
# 0                          Meddy                  212
# 1                Lemonaid Health                  415
# 2              Prellis Biologics                  415
# 3                          Memed                21212
# 4                           1859                    -
# ...                          ...                  ...
# 87706                  CellScape      Zygote Ventures
# 87707                   BioBeats  Zynik Capital Corp.
# 87708  Angiotech Pharmaceuticals           ZZ Capital
# 87709             KIMS Hospitals              ёpeople
# 87710                   Orca Bio                  NaN
#
# [87711 rows x 2 columns]

# %%
G=nx.Graph()

# %%
G = nx.from_pandas_edgelist(investordb, 'Organisation', 'Investors')

# %%
figure(figsize=(10, 8))
nx.draw_shell(G, with_labels=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 36164 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
investordb_filtered=investordb.iloc[:,[1,6]]

# %%
investordb_filtered
# Out:
#                     Organisation            Investors
# 0                          Meddy                  212
# 1                Lemonaid Health                  415
# 2              Prellis Biologics                  415
# 3                          Memed                21212
# 4                           1859                    -
# ...                          ...                  ...
# 87706                  CellScape      Zygote Ventures
# 87707                   BioBeats  Zynik Capital Corp.
# 87708  Angiotech Pharmaceuticals           ZZ Capital
# 87709             KIMS Hospitals              ёpeople
# 87710                   Orca Bio                  NaN
#
# [87711 rows x 2 columns]

# %%
matrix=pd.DataFrame(index=investordb_filtered['Investors'],columns=investordb_filtered['Investors'])

# %%
matrix.to_csv('AdjacencyMatrix')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-158-d0ebc8f2ea5e> in <module>
# ----> 1 matrix.to_csv('AdjacencyMatrix')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...

# %%
matrix2=matrix

# %%
matrix=matrix.drop(matrix.index[4:16498])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-d48537d5a283> in <module>
# ----> 1 matrix=matrix.drop(matrix.index[4:16498])
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
# ...

# %%
missing=investordb_filtered[investordb_filtered['Investors']=='-']

# %%
listadalasciare=list(missing.index)

# %%
investordb_clean=investordb_filtered.drop(investordb_filtered.index[listadalasciare])

# %%
itertools.product(investordb_clean[investordb_clean['Organisation']=='Meddy'].Investors.values)
# Out:
# [(212,),
#  ('Dharmendra Ghai',),
#  ('Innoway',),
#  ('Kasamar Holdings',),
#  ('Modus Capital',),
#  ('Qatar Science & Technology Park',)]

# %%
array1=[]
for i in itertools.combinations(investordb_clean[investordb_clean['Organisation']=='Meddy'].Investors.values,2):
    print(i)
# Out:
# (212, 'Dharmendra Ghai')
# (212, 'Innoway')
# (212, 'Kasamar Holdings')
# (212, 'Modus Capital')
# (212, 'Qatar Science & Technology Park')
# ('Dharmendra Ghai', 'Innoway')
# ('Dharmendra Ghai', 'Kasamar Holdings')
# ('Dharmendra Ghai', 'Modus Capital')
# ('Dharmendra Ghai', 'Qatar Science & Technology Park')
# ('Innoway', 'Kasamar Holdings')
# ('Innoway', 'Modus Capital')
# ('Innoway', 'Qatar Science & Technology Park')
# ('Kasamar Holdings', 'Modus Capital')
# ('Kasamar Holdings', 'Qatar Science & Technology Park')
# ('Modus Capital', 'Qatar Science & Technology Park')

# %%
array=[]
for i in investordb_clean['Organisation']:
    for j in itertools.combinations(investordb_clean[investordb_clean['Organisation']==i].Investors.values,2):
        array.append(j)

# %%
pd.Series(array).to_csv('Edges')

# %%
G=nx.Graph()

# %%
nodi=list(investordb_clean['Investors'].unique())

# %%
investordb_clean.to_csv('investordb_clean')

# %%
G.add_nodes_from(nodi)
G.add_edges_from(array)

# %%
nx.write_gexf(G, "investors.gexf")

# %%
nx.info(G)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 17975\nNumber of edges: 159851\nAverage degree:  17.7859'

# %%
hist = nx.degree_histogram(G)
    
plt.plot(range(0, len(hist)), hist, ".")
plt.title("Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("#Nodes")
# plt.loglog()
plt.show()

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('Y Combinator', 917),
#  ('OrbiMed', 826),
#  ('New Enterprise Associates', 758),
#  ('Techstars', 696),
#  ('Silicon Valley Bank', 645),
#  ('StartUp Health', 632),
#  ('Khosla Ventures', 624),
#  ('500 Startups', 591),
#  ('EASME - EU Executive Agency for SMEs', 554),
#  ('GV', 524),
#  ('Venrock', 489),
#  ('F-Prime Capital', 484),
#  ('RA Capital Management', 477),
#  ('StartX (Stanford-StartX Fund)', 474),
#  ('Polaris Partners', 470),
#  ('Inc.', 463),
#  ('Perceptive Advisors', 458),
#  ('LLC', 454),
#  ('Kleiner Perkins', 439),
#  ('National Institutes of Health', 438),
#  ('Founders Fund', 435),
#  ('MedTech Innovator', 432),
#  ('MassChallenge', 431),
#  ('Plug and Play', 427),
#  ('SV Angel', 417),
#  ('Bessemer Venture Partners', 405),
#  ('Novo Holdings', 403),
#  ('Novartis Venture Fund', 402),
#  ('Johnson & Johnson Development Corporation', 395),
#  ('Versant Ventures', 393),
#  ('Alumni Ventures Group', 389),
#  ('Western Technology Investment', 389),
# ...

# %%
density=nx.density(G)

# %%
density
# Out:
# 0.0009895362688154255

# %%
components=(nx.connected_components(G))

# %%
largest_component=max(components, key=len)

# %%
len(largest_component)
# Out:
# 14963
